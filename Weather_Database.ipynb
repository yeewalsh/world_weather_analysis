# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# generate arrays of random latitude and longitude values
lat = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(-180.000,180.000, size=2000)
lat_lngs = zip(lat, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and logitude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient count:
len(cities)
# Out:
# 752

# %%
# import requests and api_key
import requests
from config import weather_api_key

# %%
# starting URL for weather map API call:
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&lat={lat}&lon={lon}&appid=" + weather_api_key

# %%
# import the time lib and the datetime module 
import time
from datetime import datetime

# %%
# create an empty list to hold the weather data
city_data = []

# logging statements
print("Biginning Data Retrieval     ")
print("-----------------------------")

# create counters
record_count = 1
set_count = 1

# loop through all the cities in the list
for i, city in enumerate(cities):
    
    # group citiesin sets of 50 for logging purposes
    if (i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        # pause the api for 60 seconds
        time.sleep(60)

    # create endpoint url with each city, while removing spaces in the city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the url, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_description,
                              "Country": city_country,
                              "Date": city_date})

    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass


# Indicate that data loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Biginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san vicente
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | taoudenni
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | dingle
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | itoman
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | ixtapa
# Processing Record 14 of Set 1 | caravelas
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | hay river
# Processing Record 17 of Set 1 | along
# Processing Record 18 of Set 1 | nioro
# Processing Record 19 of Set 1 | pitimbu
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | rawson
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | hamilton
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | mogadishu
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | piacabucu
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | rodeo
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | matata
# Processing Record 35 of Set 1 | grindavik
# Processing Record 36 of Set 1 | goure
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | licheng
# Processing Record 40 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | hofn
# Processing Record 45 of Set 1 | pangody
# Processing Record 46 of Set 1 | manokwari
# Processing Record 47 of Set 1 | pemba
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | kati
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | otavi
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | ostrovnoy
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | gorontalo
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | shkotovo-26
# City not found. Skipping...
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | boa vista
# Processing Record 20 of Set 2 | midland
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | sorland
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | karamken
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | khasan
# Processing Record 27 of Set 2 | gawler
# Processing Record 28 of Set 2 | znamenskoye
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | lytkarino
# Processing Record 31 of Set 2 | union de reyes
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | umm kaddadah
# Processing Record 34 of Set 2 | neenah
# Processing Record 35 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | drummondville
# Processing Record 39 of Set 2 | rincon
# Processing Record 40 of Set 2 | ahipara
# Processing Record 41 of Set 2 | terekli-mekteb
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | marzuq
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | urucara
# Processing Record 48 of Set 2 | coolum beach
# Processing Record 49 of Set 2 | carson city
# Processing Record 50 of Set 2 | gobabis
# Processing Record 1 of Set 3 | soavinandriana
# Processing Record 2 of Set 3 | san policarpo
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | wahpeton
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | abu samrah
# Processing Record 8 of Set 3 | labuhan
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | kungurtug
# Processing Record 11 of Set 3 | cap malheureux
# Processing Record 12 of Set 3 | acarau
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | bubaque
# Processing Record 15 of Set 3 | hinton
# Processing Record 16 of Set 3 | elko
# Processing Record 17 of Set 3 | fereydun kenar
# Processing Record 18 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | faya
# Processing Record 21 of Set 3 | maarianhamina
# Processing Record 22 of Set 3 | gweta
# Processing Record 23 of Set 3 | ballyshannon
# Processing Record 24 of Set 3 | nizwa
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | yenotayevka
# Processing Record 28 of Set 3 | tessalit
# Processing Record 29 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | lewistown
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | wellingborough
# Processing Record 35 of Set 3 | milkovo
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | wenling
# Processing Record 38 of Set 3 | kandrian
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | paamiut
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | tommot
# Processing Record 44 of Set 3 | walvis bay
# Processing Record 45 of Set 3 | pauini
# Processing Record 46 of Set 3 | el badari
# City not found. Skipping...
# Processing Record 47 of Set 3 | caarapo
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | tammisaari
# Processing Record 2 of Set 4 | mao
# Processing Record 3 of Set 4 | nishihara
# Processing Record 4 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 4 | saint-leu
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 4 | mentakab
# Processing Record 10 of Set 4 | benemerito de las americas
# Processing Record 11 of Set 4 | makakilo city
# Processing Record 12 of Set 4 | kinsale
# Processing Record 13 of Set 4 | nuuk
# Processing Record 14 of Set 4 | nanortalik
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | berbera
# Processing Record 18 of Set 4 | parana
# Processing Record 19 of Set 4 | sobolevo
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | hami
# Processing Record 23 of Set 4 | palmer
# Processing Record 24 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 4 | rapid valley
# Processing Record 26 of Set 4 | dzaoudzi
# Processing Record 27 of Set 4 | olafsvik
# Processing Record 28 of Set 4 | atuona
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | nara
# Processing Record 32 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | ilhabela
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | melfort
# Processing Record 37 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | bonthe
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | sangar
# Processing Record 43 of Set 4 | ilinskiy
# Processing Record 44 of Set 4 | kolyubakino
# Processing Record 45 of Set 4 | hermanus
# Processing Record 46 of Set 4 | lundazi
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | hirara
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | maralal
# Processing Record 2 of Set 5 | champerico
# Processing Record 3 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 4 of Set 5 | acapulco
# Processing Record 5 of Set 5 | ventspils
# Processing Record 6 of Set 5 | anderson
# Processing Record 7 of Set 5 | leh
# Processing Record 8 of Set 5 | qaanaaq
# Processing Record 9 of Set 5 | buraydah
# Processing Record 10 of Set 5 | soure
# Processing Record 11 of Set 5 | barraute
# Processing Record 12 of Set 5 | gunnedah
# Processing Record 13 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 5 | san carlos de bariloche
# Processing Record 15 of Set 5 | jian
# Processing Record 16 of Set 5 | jamestown
# Processing Record 17 of Set 5 | seoul
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | tshane
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | praia da vitoria
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | rocha
# Processing Record 29 of Set 5 | ust-kulom
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | cervo
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 5 | lianran
# Processing Record 35 of Set 5 | tual
# Processing Record 36 of Set 5 | asau
# Processing Record 37 of Set 5 | otradnoye
# Processing Record 38 of Set 5 | samarai
# Processing Record 39 of Set 5 | maxixe
# Processing Record 40 of Set 5 | kingaroy
# Processing Record 41 of Set 5 | santa fe
# Processing Record 42 of Set 5 | san vito
# Processing Record 43 of Set 5 | kawalu
# Processing Record 44 of Set 5 | port-cartier
# Processing Record 45 of Set 5 | valera
# Processing Record 46 of Set 5 | alghero
# Processing Record 47 of Set 5 | lazaro cardenas
# Processing Record 48 of Set 5 | raga
# Processing Record 49 of Set 5 | matara
# Processing Record 50 of Set 5 | paracuru
# Processing Record 1 of Set 6 | yellowknife
# Processing Record 2 of Set 6 | akdepe
# Processing Record 3 of Set 6 | carutapera
# Processing Record 4 of Set 6 | talara
# Processing Record 5 of Set 6 | guerrero negro
# Processing Record 6 of Set 6 | manzhouli
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | kyzyl-suu
# Processing Record 11 of Set 6 | castro
# Processing Record 12 of Set 6 | tianpeng
# Processing Record 13 of Set 6 | forestville
# Processing Record 14 of Set 6 | salinopolis
# Processing Record 15 of Set 6 | uruacu
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | bilibino
# Processing Record 18 of Set 6 | cayenne
# Processing Record 19 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 6 | lucapa
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | strenci
# Processing Record 23 of Set 6 | cabedelo
# Processing Record 24 of Set 6 | manta
# Processing Record 25 of Set 6 | anupshahr
# Processing Record 26 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 6 | ketchikan
# Processing Record 28 of Set 6 | ahuimanu
# Processing Record 29 of Set 6 | padang
# Processing Record 30 of Set 6 | drabiv
# Processing Record 31 of Set 6 | moundsville
# Processing Record 32 of Set 6 | nampula
# Processing Record 33 of Set 6 | afanasyevo
# City not found. Skipping...
# Processing Record 34 of Set 6 | collecchio
# Processing Record 35 of Set 6 | kaseda
# Processing Record 36 of Set 6 | bath
# Processing Record 37 of Set 6 | sebinkarahisar
# Processing Record 38 of Set 6 | amga
# Processing Record 39 of Set 6 | mormugao
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | turukhansk
# Processing Record 42 of Set 6 | muskogee
# Processing Record 43 of Set 6 | keetmanshoop
# Processing Record 44 of Set 6 | willowmore
# Processing Record 45 of Set 6 | ekhabi
# Processing Record 46 of Set 6 | provideniya
# Processing Record 47 of Set 6 | ladario
# Processing Record 48 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 6 | manggar
# Processing Record 50 of Set 6 | palmeiras de goias
# Processing Record 1 of Set 7 | pali
# Processing Record 2 of Set 7 | vostok
# Processing Record 3 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 4 of Set 7 | tuensang
# Processing Record 5 of Set 7 | leningradskiy
# Processing Record 6 of Set 7 | mezen
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 7 | chapais
# Processing Record 10 of Set 7 | kanye
# Processing Record 11 of Set 7 | lebu
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | terra rica
# Processing Record 14 of Set 7 | srednekolymsk
# Processing Record 15 of Set 7 | khorixas
# Processing Record 16 of Set 7 | colwyn bay
# Processing Record 17 of Set 7 | meulaboh
# Processing Record 18 of Set 7 | xining
# Processing Record 19 of Set 7 | papa
# Processing Record 20 of Set 7 | montilla
# Processing Record 21 of Set 7 | san felipe
# Processing Record 22 of Set 7 | bachaquero
# Processing Record 23 of Set 7 | sola
# Processing Record 24 of Set 7 | north platte
# Processing Record 25 of Set 7 | gravdal
# Processing Record 26 of Set 7 | auki
# Processing Record 27 of Set 7 | mahebourg
# Processing Record 28 of Set 7 | nandurbar
# Processing Record 29 of Set 7 | rawah
# Processing Record 30 of Set 7 | richards bay
# Processing Record 31 of Set 7 | balingasay
# Processing Record 32 of Set 7 | kholm
# Processing Record 33 of Set 7 | payson
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | kinablangan
# Processing Record 38 of Set 7 | te anau
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | chengmai
# City not found. Skipping...
# Processing Record 41 of Set 7 | novyy urengoy
# Processing Record 42 of Set 7 | moron
# Processing Record 43 of Set 7 | saint george
# Processing Record 44 of Set 7 | oranjemund
# Processing Record 45 of Set 7 | mossoro
# Processing Record 46 of Set 7 | aracoiaba
# Processing Record 47 of Set 7 | togur
# Processing Record 48 of Set 7 | siderno
# Processing Record 49 of Set 7 | lincoln
# Processing Record 50 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 1 of Set 8 | onega
# Processing Record 2 of Set 8 | ballina
# Processing Record 3 of Set 8 | vestmanna
# Processing Record 4 of Set 8 | babol
# Processing Record 5 of Set 8 | aberdeen
# Processing Record 6 of Set 8 | la ronge
# Processing Record 7 of Set 8 | bagamoyo
# Processing Record 8 of Set 8 | comodoro rivadavia
# Processing Record 9 of Set 8 | kavaratti
# Processing Record 10 of Set 8 | harper
# Processing Record 11 of Set 8 | capao da canoa
# Processing Record 12 of Set 8 | dilla
# Processing Record 13 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 8 | araouane
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | severobaykalsk
# Processing Record 18 of Set 8 | merrill
# Processing Record 19 of Set 8 | morros
# Processing Record 20 of Set 8 | charters towers
# Processing Record 21 of Set 8 | amazar
# Processing Record 22 of Set 8 | havelock
# Processing Record 23 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | la rioja
# Processing Record 26 of Set 8 | itamaraju
# Processing Record 27 of Set 8 | byron bay
# Processing Record 28 of Set 8 | nekhayevskiy
# Processing Record 29 of Set 8 | waipawa
# Processing Record 30 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 31 of Set 8 | monroe
# Processing Record 32 of Set 8 | sipe sipe
# Processing Record 33 of Set 8 | joao camara
# Processing Record 34 of Set 8 | kumo
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | mbanza-ngungu
# Processing Record 37 of Set 8 | port blair
# Processing Record 38 of Set 8 | nawabganj
# Processing Record 39 of Set 8 | susaki
# Processing Record 40 of Set 8 | teya
# Processing Record 41 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 8 | sahbuz
# Processing Record 43 of Set 8 | tarana
# Processing Record 44 of Set 8 | russkaya polyana
# Processing Record 45 of Set 8 | baoshan
# Processing Record 46 of Set 8 | huarmey
# Processing Record 47 of Set 8 | klaksvik
# Processing Record 48 of Set 8 | saint-ambroise
# Processing Record 49 of Set 8 | pevek
# Processing Record 50 of Set 8 | baoding
# Processing Record 1 of Set 9 | strezhevoy
# Processing Record 2 of Set 9 | kuching
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | vieux-habitants
# Processing Record 5 of Set 9 | gwadar
# Processing Record 6 of Set 9 | satuba
# Processing Record 7 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 9 | xocali
# Processing Record 9 of Set 9 | pacific grove
# Processing Record 10 of Set 9 | emba
# Processing Record 11 of Set 9 | kentau
# Processing Record 12 of Set 9 | amiens
# Processing Record 13 of Set 9 | baykit
# Processing Record 14 of Set 9 | kropotkin
# Processing Record 15 of Set 9 | alta floresta
# Processing Record 16 of Set 9 | zhigansk
# Processing Record 17 of Set 9 | ko samui
# Processing Record 18 of Set 9 | nyuksenitsa
# Processing Record 19 of Set 9 | terney
# Processing Record 20 of Set 9 | massena
# Processing Record 21 of Set 9 | yining
# Processing Record 22 of Set 9 | tifton
# Processing Record 23 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 9 | aykhal
# Processing Record 25 of Set 9 | chauk
# Processing Record 26 of Set 9 | luau
# Processing Record 27 of Set 9 | jardim
# Processing Record 28 of Set 9 | oistins
# Processing Record 29 of Set 9 | inhambane
# Processing Record 30 of Set 9 | yuzhnyy
# Processing Record 31 of Set 9 | korla
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | tazovskiy
# Processing Record 34 of Set 9 | potsdam
# Processing Record 35 of Set 9 | saryozek
# Processing Record 36 of Set 9 | saint anthony
# Processing Record 37 of Set 9 | mata
# Processing Record 38 of Set 9 | brae
# Processing Record 39 of Set 9 | wajima
# Processing Record 40 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 9 | ostersund
# Processing Record 42 of Set 9 | poya
# Processing Record 43 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 9 | lorengau
# Processing Record 45 of Set 9 | henties bay
# Processing Record 46 of Set 9 | solnechnyy
# Processing Record 47 of Set 9 | tiznit
# Processing Record 48 of Set 9 | batagay
# Processing Record 49 of Set 9 | petranka
# Processing Record 50 of Set 9 | novaya lyalya
# Processing Record 1 of Set 10 | iqaluit
# Processing Record 2 of Set 10 | haimen
# Processing Record 3 of Set 10 | chalmette
# Processing Record 4 of Set 10 | mayo
# Processing Record 5 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 10 | hauterive
# Processing Record 7 of Set 10 | rancho palos verdes
# Processing Record 8 of Set 10 | awbari
# Processing Record 9 of Set 10 | arlit
# Processing Record 10 of Set 10 | aksarayskiy
# Processing Record 11 of Set 10 | dawei
# Processing Record 12 of Set 10 | el molino
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | husavik
# Processing Record 15 of Set 10 | nata
# Processing Record 16 of Set 10 | sampit
# Processing Record 17 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 10 | puerto del rosario
# Processing Record 19 of Set 10 | panguna
# Processing Record 20 of Set 10 | bambous virieux
# Processing Record 21 of Set 10 | komsomolskiy
# Processing Record 22 of Set 10 | lethem
# Processing Record 23 of Set 10 | upata
# Processing Record 24 of Set 10 | paita
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | roma
# Processing Record 27 of Set 10 | ulundi
# Processing Record 28 of Set 10 | lalmohan
# Processing Record 29 of Set 10 | nowy dwor gdanski
# Processing Record 30 of Set 10 | novyy rogachik
# Processing Record 31 of Set 10 | osypenko
# Processing Record 32 of Set 10 | juigalpa
# Processing Record 33 of Set 10 | casablanca
# Processing Record 34 of Set 10 | cockburn town
# Processing Record 35 of Set 10 | garissa
# Processing Record 36 of Set 10 | eureka
# Processing Record 37 of Set 10 | mwaya
# Processing Record 38 of Set 10 | waddan
# Processing Record 39 of Set 10 | kragujevac
# Processing Record 40 of Set 10 | geraldton
# Processing Record 41 of Set 10 | morondava
# Processing Record 42 of Set 10 | urlati
# Processing Record 43 of Set 10 | mecca
# Processing Record 44 of Set 10 | port-gentil
# Processing Record 45 of Set 10 | kiunga
# Processing Record 46 of Set 10 | high level
# Processing Record 47 of Set 10 | bijar
# Processing Record 48 of Set 10 | sweetwater
# Processing Record 49 of Set 10 | bloomfield
# Processing Record 50 of Set 10 | chumikan
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | shimoda
# Processing Record 3 of Set 11 | helena
# Processing Record 4 of Set 11 | natal
# Processing Record 5 of Set 11 | etchoropo
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | san andres
# Processing Record 8 of Set 11 | santiago del estero
# Processing Record 9 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 11 | bela
# Processing Record 11 of Set 11 | villamaria
# Processing Record 12 of Set 11 | half moon bay
# Processing Record 13 of Set 11 | fria
# Processing Record 14 of Set 11 | bud
# Processing Record 15 of Set 11 | anadyr
# Processing Record 16 of Set 11 | vichayal
# City not found. Skipping...
# Processing Record 17 of Set 11 | puerto escondido
# Processing Record 18 of Set 11 | touros
# Processing Record 19 of Set 11 | egvekinot
# Processing Record 20 of Set 11 | turbat
# Processing Record 21 of Set 11 | san patricio
# Processing Record 22 of Set 11 | chagoda
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | vila
# Processing Record 25 of Set 11 | varhaug
# Processing Record 26 of Set 11 | soyo
# Processing Record 27 of Set 11 | japura
# Processing Record 28 of Set 11 | rio gallegos
# Processing Record 29 of Set 11 | tilichiki
# Processing Record 30 of Set 11 | ciudad bolivar
# Processing Record 31 of Set 11 | bom jesus
# Processing Record 32 of Set 11 | alugan
# Processing Record 33 of Set 11 | berlevag
# Processing Record 34 of Set 11 | iskateley
# Processing Record 35 of Set 11 | ajdabiya
# Processing Record 36 of Set 11 | kalamare
# Processing Record 37 of Set 11 | mersing
# Processing Record 38 of Set 11 | ilulissat
# Processing Record 39 of Set 11 | flagstaff
# Processing Record 40 of Set 11 | college
# Processing Record 41 of Set 11 | ulaangom
# Processing Record 42 of Set 11 | straumen
# Processing Record 43 of Set 11 | concordia
# Processing Record 44 of Set 11 | gaogou
# Processing Record 45 of Set 11 | baruun-urt
# Processing Record 46 of Set 11 | epe
# Processing Record 47 of Set 11 | vanimo
# Processing Record 48 of Set 11 | kilakarai
# Processing Record 49 of Set 11 | mayor pablo lagerenza
# Processing Record 50 of Set 11 | kunya
# Processing Record 1 of Set 12 | ponta delgada
# Processing Record 2 of Set 12 | mayumba
# Processing Record 3 of Set 12 | chenghai
# Processing Record 4 of Set 12 | portales
# Processing Record 5 of Set 12 | aklavik
# Processing Record 6 of Set 12 | azusa
# Processing Record 7 of Set 12 | langsa
# Processing Record 8 of Set 12 | grand gaube
# Processing Record 9 of Set 12 | seabra
# Processing Record 10 of Set 12 | plainview
# Processing Record 11 of Set 12 | sao felix do xingu
# Processing Record 12 of Set 12 | arman
# Processing Record 13 of Set 12 | premnitz
# Processing Record 14 of Set 12 | clemencia
# Processing Record 15 of Set 12 | san juan
# Processing Record 16 of Set 12 | radford
# Processing Record 17 of Set 12 | kirovskiy
# Processing Record 18 of Set 12 | uthal
# Processing Record 19 of Set 12 | vao
# Processing Record 20 of Set 12 | mahenge
# Processing Record 21 of Set 12 | bloemhof
# Processing Record 22 of Set 12 | burica
# City not found. Skipping...
# Processing Record 23 of Set 12 | san bartolome de tirajana
# Processing Record 24 of Set 12 | borshchiv
# Processing Record 25 of Set 12 | espoo
# Processing Record 26 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 27 of Set 12 | pryshyb
# Processing Record 28 of Set 12 | kudahuvadhoo
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | rovinj
# Processing Record 31 of Set 12 | barcelos
# Processing Record 32 of Set 12 | mae sai
# Processing Record 33 of Set 12 | ola
# Processing Record 34 of Set 12 | altamont
# Processing Record 35 of Set 12 | yvetot
# Processing Record 36 of Set 12 | jalu
# Processing Record 37 of Set 12 | lloydminster
# Processing Record 38 of Set 12 | cam ranh
# Processing Record 39 of Set 12 | almaty
# Processing Record 40 of Set 12 | yerbogachen
# Processing Record 41 of Set 12 | kvareli
# Processing Record 42 of Set 12 | lavrentiya
# Processing Record 43 of Set 12 | naqadeh
# Processing Record 44 of Set 12 | port lincoln
# Processing Record 45 of Set 12 | beringovskiy
# Processing Record 46 of Set 12 | steamboat springs
# Processing Record 47 of Set 12 | ponta do sol
# Processing Record 48 of Set 12 | souillac
# Processing Record 49 of Set 12 | letterkenny
# Processing Record 50 of Set 12 | vegreville
# Processing Record 1 of Set 13 | beloha
# Processing Record 2 of Set 13 | koumac
# Processing Record 3 of Set 13 | ortona
# Processing Record 4 of Set 13 | kutum
# Processing Record 5 of Set 13 | keningau
# Processing Record 6 of Set 13 | vysokogornyy
# Processing Record 7 of Set 13 | norman wells
# Processing Record 8 of Set 13 | haysyn
# Processing Record 9 of Set 13 | marsh harbour
# Processing Record 10 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 13 | salinas
# Processing Record 12 of Set 13 | aksu
# Processing Record 13 of Set 13 | ancud
# Processing Record 14 of Set 13 | bukachacha
# Processing Record 15 of Set 13 | pingliang
# Processing Record 16 of Set 13 | general roca
# Processing Record 17 of Set 13 | noboribetsu
# Processing Record 18 of Set 13 | mount darwin
# Processing Record 19 of Set 13 | prince rupert
# Processing Record 20 of Set 13 | jining
# Processing Record 21 of Set 13 | lima
# Processing Record 22 of Set 13 | teonthar
# Processing Record 23 of Set 13 | mareeba
# Processing Record 24 of Set 13 | boguchar
# Processing Record 25 of Set 13 | chimbote
# Processing Record 26 of Set 13 | sept-iles
# Processing Record 27 of Set 13 | tori
# Processing Record 28 of Set 13 | ouadda
# Processing Record 29 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 13 | victoria
# Processing Record 31 of Set 13 | malaut
# Processing Record 32 of Set 13 | wahiawa
# Processing Record 33 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | maniitsoq
# Processing Record 36 of Set 13 | saint-georges
# Processing Record 37 of Set 13 | weinan
# Processing Record 38 of Set 13 | saravena
# Processing Record 39 of Set 13 | russell
# Processing Record 40 of Set 13 | saiki
# Processing Record 41 of Set 13 | marfino
# Processing Record 42 of Set 13 | killybegs
# Processing Record 43 of Set 13 | banjar
# Processing Record 44 of Set 13 | kavieng
# Processing Record 45 of Set 13 | chiang khong
# Processing Record 46 of Set 13 | broome
# Processing Record 47 of Set 13 | guanica
# Processing Record 48 of Set 13 | casambalangan
# Processing Record 49 of Set 13 | hailar
# Processing Record 50 of Set 13 | kununurra
# Processing Record 1 of Set 14 | vieques
# Processing Record 2 of Set 14 | pundaguitan
# Processing Record 3 of Set 14 | kirakira
# Processing Record 4 of Set 14 | yazman
# Processing Record 5 of Set 14 | cururupu
# Processing Record 6 of Set 14 | savannakhet
# Processing Record 7 of Set 14 | salto
# Processing Record 8 of Set 14 | riyadh
# Processing Record 9 of Set 14 | coruripe
# Processing Record 10 of Set 14 | las tunas
# Processing Record 11 of Set 14 | verkhoyansk
# Processing Record 12 of Set 14 | naze
# Processing Record 13 of Set 14 | kenora
# Processing Record 14 of Set 14 | birao
# Processing Record 15 of Set 14 | alofi
# Processing Record 16 of Set 14 | ambon
# Processing Record 17 of Set 14 | metu
# Processing Record 18 of Set 14 | kurikka
# Processing Record 19 of Set 14 | virginia beach
# Processing Record 20 of Set 14 | avera
# Processing Record 21 of Set 14 | shelburne
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | raudeberg
# Processing Record 24 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 14 | lata
# Processing Record 26 of Set 14 | luyang
# Processing Record 27 of Set 14 | farafangana
# Processing Record 28 of Set 14 | zouxian
# City not found. Skipping...
# Processing Record 29 of Set 14 | bulgan
# Processing Record 30 of Set 14 | lepe
# Processing Record 31 of Set 14 | ugoofaaru
# Processing Record 32 of Set 14 | morant bay
# Processing Record 33 of Set 14 | akyab
# Processing Record 34 of Set 14 | rudbar
# Processing Record 35 of Set 14 | hit
# City not found. Skipping...
# Processing Record 36 of Set 14 | mehamn
# City not found. Skipping...
# Processing Record 37 of Set 14 | la paz
# City not found. Skipping...
# Processing Record 38 of Set 14 | yushan
# Processing Record 39 of Set 14 | bahia blanca
# Processing Record 40 of Set 14 | alice springs
# Processing Record 41 of Set 14 | nelson bay
# Processing Record 42 of Set 14 | chiknayakanhalli
# Processing Record 43 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 14 | loandjili
# Processing Record 45 of Set 14 | boca do acre
# Processing Record 46 of Set 14 | vzmorye
# Processing Record 47 of Set 14 | knysna
# Processing Record 48 of Set 14 | zeerust
# Processing Record 49 of Set 14 | tateyama
# Processing Record 50 of Set 14 | totma
# Processing Record 1 of Set 15 | bella vista
# Processing Record 2 of Set 15 | chilliwack
# Processing Record 3 of Set 15 | kushima
# Processing Record 4 of Set 15 | tahe
# Processing Record 5 of Set 15 | nichinan
# Processing Record 6 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 15 | luderitz
# Processing Record 8 of Set 15 | grajau
# Processing Record 9 of Set 15 | alvdal
# Processing Record 10 of Set 15 | providencia
# Processing Record 11 of Set 15 | rach gia
# Processing Record 12 of Set 15 | freeport
# Processing Record 13 of Set 15 | telford
# Processing Record 14 of Set 15 | javanrud
# Processing Record 15 of Set 15 | tacoronte
# Processing Record 16 of Set 15 | constantine
# Processing Record 17 of Set 15 | lozuvatka
# Processing Record 18 of Set 15 | floro
# Processing Record 19 of Set 15 | jackson
# Processing Record 20 of Set 15 | sao joao da barra
# Processing Record 21 of Set 15 | sitrah
# Processing Record 22 of Set 15 | chateau-gontier
# Processing Record 23 of Set 15 | wanaka
# Processing Record 24 of Set 15 | doha
# Processing Record 25 of Set 15 | evensk
# Processing Record 26 of Set 15 | valparaiso
# Processing Record 27 of Set 15 | singarayakonda
# Processing Record 28 of Set 15 | tartki
# City not found. Skipping...
# Processing Record 29 of Set 15 | port antonio
# Processing Record 30 of Set 15 | saint-paul
# Processing Record 31 of Set 15 | tapa
# Processing Record 32 of Set 15 | warwick
# Processing Record 33 of Set 15 | kohima
# Processing Record 34 of Set 15 | sioux lookout
# Processing Record 35 of Set 15 | vilyuysk
# Processing Record 36 of Set 15 | narni
# Processing Record 37 of Set 15 | kibre mengist
# Processing Record 38 of Set 15 | inta
# Processing Record 39 of Set 15 | juneau
# Processing Record 40 of Set 15 | mackay
# Processing Record 41 of Set 15 | salamiyah
# Processing Record 42 of Set 15 | road town
# Processing Record 43 of Set 15 | zyryanka
# Processing Record 44 of Set 15 | fort nelson
# Processing Record 45 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 15 | issa
# Processing Record 47 of Set 15 | taganak
# Processing Record 48 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 15 | bontang
# Processing Record 50 of Set 15 | maryborough
# Processing Record 1 of Set 16 | sistranda
# Processing Record 2 of Set 16 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# count the number of cities collected
print(len(city_data))
# Out:
# 685

# %%
# convert the array of dictionaries into a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       San Vicente -26.6167  -54.1333     55.67        85           5
# 1    Saint-Philippe -21.3585   55.7679     73.22        87          62
# 2      Punta Arenas -53.1500  -70.9167     46.11        93          75
# 3         Taoudenni  22.6783   -3.9836     76.91        22           3
# 4             Bluff -46.6000  168.3333     60.80        67          11
# ..              ...      ...       ...       ...       ...         ...
# 680         Taganak   6.0833  118.3000     82.54        73          14
# 681         Bontang   0.1333  117.5000     82.02        78          77
# 682     Maryborough -25.5333  152.7000     77.11        48          41
# 683       Sistranda  63.7256    8.8340     46.36        80          89
# 684            Hovd  48.0056   91.6419     45.70        21           1
#
#      Wind Speed Current Description Country                 Date
# 0          1.99           clear sky      AR  2022-04-18 00:14:02
# 1          9.06          light rain      RE  2022-04-18 00:04:21
# 2          8.05       broken clouds      CL  2022-04-18 00:09:44
# 3          9.40           clear sky      ML  2022-04-18 00:14:03
# 4          5.39          few clouds      NZ  2022-04-18 00:12:26
# ..          ...                 ...     ...                  ...
# 680        4.23          few clouds      PH  2022-04-18 00:33:48
# 681        7.70       broken clouds      ID  2022-04-18 00:33:49
# 682        7.09    scattered clouds      AU  2022-04-18 00:33:49
# 683        5.93     overcast clouds      NO  2022-04-18 00:34:50
# 684        6.49           clear sky      MN  2022-04-18 00:34:51
#
# [685 rows x 10 columns]

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

# Assign the new column order to the DF
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0       San Vicente      AR -26.6167  -54.1333     55.67        85
# 1    Saint-Philippe      RE -21.3585   55.7679     73.22        87
# 2      Punta Arenas      CL -53.1500  -70.9167     46.11        93
# 3         Taoudenni      ML  22.6783   -3.9836     76.91        22
# 4             Bluff      NZ -46.6000  168.3333     60.80        67
# ..              ...     ...      ...       ...       ...       ...
# 680         Taganak      PH   6.0833  118.3000     82.54        73
# 681         Bontang      ID   0.1333  117.5000     82.02        78
# 682     Maryborough      AU -25.5333  152.7000     77.11        48
# 683       Sistranda      NO  63.7256    8.8340     46.36        80
# 684            Hovd      MN  48.0056   91.6419     45.70        21
#
#      Cloudiness  Wind Speed Current Description
# 0             5        1.99           clear sky
# 1            62        9.06          light rain
# 2            75        8.05       broken clouds
# 3             3        9.40           clear sky
# 4            11        5.39          few clouds
# ..          ...         ...                 ...
# 680          14        4.23          few clouds
# 681          77        7.70       broken clouds
# 682          41        7.09    scattered clouds
# 683          89        5.93     overcast clouds
# 684           1        6.49           clear sky
#
# [685 rows x 9 columns]

# %%
# create the output file csv
output_data_file = "WeatherPy_Database.csv"
# Export the city_Data to a csv
city_data_df.to_csv(output_data_file, index_label="City ID")
